# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
fashiondata=keras.datasets.fashion_mnist

# %%
(train_image,train_label),(test_image,test_label)=fashiondata.load_data()
plt.imshow(train_image[10])
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
train_image=train_image/255
test_image=test_image/255

# %%
model= tf.keras.Sequential([
                            tf.keras.layers.Conv2D(32,(3,3),padding='same',input_shape=(28,28,1)),
                            tf.keras.layers.BatchNormalization(),

                            tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same'),
                            tf.keras.layers.BatchNormalization(),

                            tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same'),
                            tf.keras.layers.BatchNormalization(),

                            #tf.keras.layers.Conv2D(32,(3,3)),
                            #tf.keras.layers.BatchNormalization(),
                          
                            tf.keras.layers.Flatten(),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(10,activation='softmax')
])

print(model.summary())
model.compile(optimizer="Adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"]
             )
model.fit(train_image,train_label,epochs=5)

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  batch_normalization (BatchN  (None, 28, 28, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 14, 14, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  batch_normalization_2 (Batc  (None, 7, 7, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 128)               200832
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 221,322
# Trainable params: 221,130
# Non-trainable params: 192
# _________________________________________________________________
# None
# Epoch 1/5
# ...

# %%
model.fit(test_image,test_label,epochs=5)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3508 - accuracy: 0.8808
# Epoch 2/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2286 - accuracy: 0.9146
# Epoch 3/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1672 - accuracy: 0.9396
# Epoch 4/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1272 - accuracy: 0.9547
# Epoch 5/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0974 - accuracy: 0.9665

# %%
model.predict(test_image)[8]
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([1.3208672e-10, 7.2618913e-13, 9.5411909e-09, 7.2855118e-11,
#        5.7980891e-11, 1.0000000e+00, 1.5203583e-10, 7.5898283e-09,
#        2.3618221e-09, 3.2695451e-14], dtype=float32)

# %%
model1= tf.keras.Sequential([
                            tf.keras.layers.Conv2D(32,(3,3),padding='same',input_shape=(28,28,1)),
                            

                            tf.keras.layers.Conv2D(32,(3,3),padding='same'),

                            tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same'),
                            tf.keras.layers.BatchNormalization(),

                            #tf.keras.layers.Conv2D(32,(3,3)),
                            #tf.keras.layers.BatchNormalization(),
                          
                            tf.keras.layers.Flatten(),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(10,activation='softmax')
])

print(model1.summary())
model1.compile(optimizer="Adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"]
             )
model1.fit(train_image,train_label,epochs=5)

print(model1.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 32)        9248
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_3 (Batc  (None, 14, 14, 32)       128
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_2 (Dense)             (None, 128)               802944
#
#  dense_3 (Dense)             (None, 10)                1290
#
# ...
# Total params: 823,178
# Trainable params: 823,114
# Non-trainable params: 64
# _________________________________________________________________
# None
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4650 - accuracy: 0.8368
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3433 - accuracy: 0.8748
# Epoch 3/5
# ...

# %%
model1.fit(test_image,test_label,epochs=5)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3753 - accuracy: 0.8656
# Epoch 2/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2575 - accuracy: 0.9057
# Epoch 3/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1961 - accuracy: 0.9252
# Epoch 4/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1527 - accuracy: 0.9427
# Epoch 5/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1179 - accuracy: 0.9591

# %%
model1.predict(test_image)[8]
# Out:
# 313/313 [==============================] - 0s 1ms/step
# array([4.39827869e-10, 6.93566569e-13, 3.06966453e-12, 1.01586884e-13,
#        2.64474899e-15, 1.00000000e+00, 2.07915542e-12, 1.34422484e-09,
#        4.86187488e-16, 1.34041758e-13], dtype=float32)

# %%
model2= tf.keras.Sequential([
                            tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same',input_shape=(28,28,1)),
                            

                            #tf.keras.layers.Conv2D(32,(3,3),padding='same'),

                            #tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same'),
                            #tf.keras.layers.BatchNormalization(),

                            #tf.keras.layers.Conv2D(32,(3,3)),
                            #tf.keras.layers.BatchNormalization(),
                          
                            tf.keras.layers.Flatten(),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(10,activation='softmax')
])

print(model2.summary())
model2.compile(optimizer="Adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"]
             )
model2.fit(train_image,train_label,epochs=5)

print(model2.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 14, 14, 32)        320
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_4 (Dense)             (None, 128)               802944
#
#  dense_5 (Dense)             (None, 10)                1290
#
# ...
# Total params: 804,554
# Trainable params: 804,554
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4385 - accuracy: 0.8436
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3154 - accuracy: 0.8860
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2635 - accuracy: 0.9027
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2246 - accuracy: 0.9168
# Epoch 5/5
# ...

# %%
model2.fit(test_image,test_label,epochs=5)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3471 - accuracy: 0.8815
# Epoch 2/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2133 - accuracy: 0.9215
# Epoch 3/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1578 - accuracy: 0.9438
# Epoch 4/5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1204 - accuracy: 0.9595
# Epoch 5/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0882 - accuracy: 0.9710

# %%
model2.predict(test_image)[8]
# Out:
# 313/313 [==============================] - 0s 1ms/step
# array([1.84464238e-06, 8.89097074e-10, 2.87323965e-09, 1.49391079e-12,
#        6.70950968e-12, 9.99998093e-01, 1.68665326e-09, 8.54061710e-10,
#        1.25095784e-11, 3.56665245e-15], dtype=float32)

# %%
model3= tf.keras.Sequential([
                            tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same',input_shape=(28,28,1)),
                            

                            #tf.keras.layers.Conv2D(32,(3,3),padding='same'),

                            #tf.keras.layers.Conv2D(32,(3,3),strides=(2, 2),padding='same'),
                            #tf.keras.layers.BatchNormalization(),

                            #tf.keras.layers.Conv2D(32,(3,3)),
                            #tf.keras.layers.BatchNormalization(),
                          
                            tf.keras.layers.Flatten(),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(10,activation='softmax')
])

print(model3.summary())
model3.compile(optimizer="Adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"]
             )
model3.fit(train_image,train_label,epochs=5)

print(model3.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_7 (Conv2D)           (None, 14, 14, 32)        320
#
#  flatten_3 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None, 128)               802944
#
#  dense_7 (Dense)             (None, 10)                1290
#
# ...
# Total params: 804,554
# Trainable params: 804,554
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4440 - accuracy: 0.8411
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3157 - accuracy: 0.8846
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2622 - accuracy: 0.9028
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2226 - accuracy: 0.9172
# Epoch 5/5
# ...

# %%
model3.fit(test_image,test_label,epochs=5)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3537 - accuracy: 0.8761
# Epoch 2/5
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2130 - accuracy: 0.9233
# Epoch 3/5
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1558 - accuracy: 0.9448
# Epoch 4/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1167 - accuracy: 0.9617
# Epoch 5/5
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0873 - accuracy: 0.9726

# %%
model3.predict(test_image)[8]
# Out:
# 313/313 [==============================] - 0s 1ms/step
# array([5.5788050e-08, 5.2989921e-11, 1.5917063e-07, 1.6938292e-09,
#        6.6038339e-09, 9.9999976e-01, 2.6950375e-09, 1.4564088e-09,
#        1.0617600e-09, 5.3080554e-11], dtype=float32)
